// %% [markdown]
// # Retail Data Wrangling and Analytics

// %%
%scala
// Load the table into a Spark DataFrame
val df = spark.table("jarvis_workspace.default.online_retail_ii")
df.show(5)
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">+-------+---------+--------------------+--------+-------------------+-----+-----------+--------------+
// Invoice|StockCode|         Description|Quantity|        InvoiceDate|Price|Customer ID|       Country|
// +-------+---------+--------------------+--------+-------------------+-----+-----------+--------------+
//  489434|    85048|15CM CHRISTMAS GL...|      12|2009-12-01 07:45:00| 6.95|    13085.0|United Kingdom|
//  489434|   79323P|  PINK CHERRY LIGHTS|      12|2009-12-01 07:45:00| 6.75|    13085.0|United Kingdom|
//  489434|   79323W| WHITE CHERRY LIGHTS|      12|2009-12-01 07:45:00| 6.75|    13085.0|United Kingdom|
//  489434|    22041|RECORD FRAME 7&quot; S...|      48|2009-12-01 07:45:00|  2.1|    13085.0|United Kingdom|
//  489434|    21232|STRAWBERRY CERAMI...|      24|2009-12-01 07:45:00| 1.25|    13085.0|United Kingdom|
// +-------+---------+--------------------+--------+-------------------+-----+-----------+--------------+
// only showing top 5 rows
//
// df: org.apache.spark.sql.DataFrame = [Invoice: string, StockCode: string ... 6 more fields]
// </div>

// %%
%scala
//imports
import org.apache.spark.sql.functions._
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">import org.apache.spark.sql.functions._
// </div>

// %%
%scala
df.printSchema()
df.describe().show()
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">root
// -- Invoice: string (nullable = true)
// -- StockCode: string (nullable = true)
// -- Description: string (nullable = true)
// -- Quantity: long (nullable = true)
// -- InvoiceDate: timestamp (nullable = true)
// -- Price: double (nullable = true)
// -- Customer ID: double (nullable = true)
// -- Country: string (nullable = true)
//
// +-------+------------------+------------------+--------------------+------------------+------------------+------------------+-----------+
// summary|           Invoice|         StockCode|         Description|          Quantity|             Price|       Customer ID|    Country|
// +-------+------------------+------------------+--------------------+------------------+------------------+------------------+-----------+
//   count|           1067371|           1067371|             1062989|           1067371|           1067371|            824364|    1067371|
//    mean| 537608.1499316233|29011.161534536903|            21848.25|   9.9388984711033| 4.649387727411549| 15324.63850435002|       NULL|
//  stddev|26662.450446912317| 18822.94286618921|   922.9197780233488|172.70579407675424|123.55305872146386|1697.4644503793172|       NULL|
//     min|            489434|             10002|  DOORMAT UNION J...|            -80995|         -53594.36|           12346.0|  Australia|
//     max|           C581569|                 m|   wrongly sold sets|             80995|           38970.0|           18287.0|West Indies|
// +-------+------------------+------------------+--------------------+------------------+------------------+------------------+-----------+
//
// </div>

// %% [markdown]
// # Total Invoice Amount Distribution

// %% [markdown]
// ## Calculate Invoice Total

// %%
%scala

// Create column that displays total price of the items
val itemsTotal = df.withColumn("ItemsTotal",$"Quantity" * $"Price")

val invoiceTotal = itemsTotal
    .filter($"ItemsTotal" > 0)
    .groupBy("Invoice")
    .agg(sum("ItemsTotal").alias("ItemsTotal"))

invoiceTotal.show()
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">+-------+------------------+
// Invoice|        ItemsTotal|
// +-------+------------------+
//  489677|             192.0|
//  491045|             303.2|
//  491658|155.05999999999997|
//  493542|            118.75|
//  493977|            275.95|
//  494244|            6711.0|
//  494277|           1335.92|
//  495185|           2507.06|
//  495783|             48.96|
//  496171|199.29999999999998|
//  496233|188.82999999999998|
//  496427|291.14000000000004|
//  497229| 312.5899999999999|
//  498070|207.15000000000006|
//  498125|190.95000000000005|
//  498328|            275.04|
//  498934|             899.0|
//  500148|431.59000000000015|
//  500253|             18.85|
//  500903|           2655.96|
// +-------+------------------+
// only showing top 20 rows
//
// itemsTotal: org.apache.spark.sql.DataFrame = [Invoice: string, StockCode: string ... 7 more fields]
// invoiceTotal: org.apache.spark.sql.DataFrame = [Invoice: string, ItemsTotal: double]
// </div>

// %% [markdown]
// ## Calculate Min, Max, Mean, Median, and Mode Values and Draw Distribution Amount

// %%
%scala
val minTotal = invoiceTotal.agg(min("ItemsTotal")).as[Double].first()
val maxTotal = invoiceTotal.agg(max("ItemsTotal")).as[Double].first()
val medianTotal = invoiceTotal.stat.approxQuantile("ItemsTotal", Array(0.5), 0.0)(0)
val modeTotalDF = invoiceTotal.groupBy("ItemsTotal").count().orderBy(desc("count"))
val modeTotal = modeTotalDF.first().getAs[Double]("ItemsTotal")
val meanTotal = invoiceTotal.agg(avg("ItemsTotal")).as[Double].first()

println(f"Minimum: $minTotal%.2f")
println(f"Mean: $meanTotal%.2f")
println(f"Median: $medianTotal%.2f")
println(f"Mode: $modeTotal%.2f")
println(f"Maximum: $maxTotal%.2f")

display(invoiceTotal)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Invoice</th><th>ItemsTotal</th></tr></thead><tbody><tr><td>489677</td><td>192.0</td></tr><tr><td>491045</td><td>303.2</td></tr><tr><td>491658</td><td>155.05999999999997</td></tr><tr><td>493542</td><td>118.75</td></tr><tr><td>493977</td><td>275.95</td></tr><tr><td>494244</td><td>6711.0</td></tr><tr><td>494277</td><td>1335.92</td></tr><tr><td>495185</td><td>2507.06</td></tr><tr><td>495783</td><td>48.96</td></tr><tr><td>496171</td><td>199.29999999999998</td></tr><tr><td>496233</td><td>188.82999999999998</td></tr><tr><td>496427</td><td>291.14000000000004</td></tr><tr><td>497229</td><td>312.5899999999999</td></tr><tr><td>498070</td><td>207.15000000000006</td></tr><tr><td>498125</td><td>190.95000000000005</td></tr><tr><td>498328</td><td>275.04</td></tr><tr><td>498934</td><td>899.0</td></tr><tr><td>500148</td><td>431.59000000000015</td></tr><tr><td>500253</td><td>18.85</td></tr><tr><td>500903</td><td>2655.96</td></tr><tr><td>500979</td><td>11.9</td></tr><tr><td>501046</td><td>612.0</td></tr><tr><td>502610</td><td>1103.85</td></tr><tr><td>502620</td><td>172.35</td></tr><tr><td>502860</td><td>106.96000000000001</td></tr><tr><td>503942</td><td>304.33</td></tr><tr><td>504372</td><td>315.84999999999997</td></tr><tr><td>505024</td><td>216.54</td></tr><tr><td>505703</td><td>328.48</td></tr><tr><td>506092</td><td>105.71</td></tr><tr><td>506258</td><td>306.2</td></tr><tr><td>507206</td><td>673.8599999999998</td></tr><tr><td>507464</td><td>1621.7999999999997</td></tr><tr><td>508195</td><td>207.35999999999999</td></tr><tr><td>508647</td><td>60.0</td></tr><tr><td>508840</td><td>112.94</td></tr><tr><td>508905</td><td>160.4</td></tr><tr><td>508953</td><td>100.8</td></tr><tr><td>509891</td><td>4.25</td></tr><tr><td>510434</td><td>30.499999999999993</td></tr><tr><td>510436</td><td>180.65</td></tr><tr><td>510516</td><td>270.04999999999995</td></tr><tr><td>510761</td><td>65.05000000000001</td></tr><tr><td>511135</td><td>511.0399999999999</td></tr><tr><td>511668</td><td>319.6</td></tr><tr><td>511761</td><td>298.55</td></tr><tr><td>511789</td><td>433.97999999999996</td></tr><tr><td>513264</td><td>765.0</td></tr><tr><td>513575</td><td>333.6</td></tr><tr><td>513652</td><td>185.46</td></tr><tr><td>514019</td><td>313.94999999999993</td></tr><tr><td>514838</td><td>135.46000000000004</td></tr><tr><td>514951</td><td>162.24</td></tr><tr><td>515016</td><td>273.96000000000004</td></tr><tr><td>515937</td><td>130.64</td></tr><tr><td>501304</td><td>270.9200000000001</td></tr><tr><td>504328</td><td>355.18999999999994</td></tr><tr><td>507425</td><td>360.9000000000001</td></tr><tr><td>489460</td><td>485.7900000000001</td></tr><tr><td>489812</td><td>597.6899999999999</td></tr><tr><td>489824</td><td>176.87999999999997</td></tr><tr><td>489915</td><td>54.599999999999994</td></tr><tr><td>490100</td><td>869.9300000000001</td></tr><tr><td>490465</td><td>933.35</td></tr><tr><td>490526</td><td>533.9699999999999</td></tr><tr><td>490534</td><td>263.67999999999995</td></tr><tr><td>490538</td><td>504.53999999999996</td></tr><tr><td>490657</td><td>208.83</td></tr><tr><td>490881</td><td>10.0</td></tr><tr><td>491394</td><td>404.82</td></tr><tr><td>491724</td><td>124.89999999999999</td></tr><tr><td>492785</td><td>485.40000000000003</td></tr><tr><td>493816</td><td>212.0</td></tr><tr><td>494395</td><td>953.5000000000006</td></tr><tr><td>494997</td><td>228.96</td></tr><tr><td>498350</td><td>299.52000000000004</td></tr><tr><td>498648</td><td>367.6</td></tr><tr><td>499971</td><td>268.67999999999995</td></tr><tr><td>501464</td><td>205.56</td></tr><tr><td>501850</td><td>144.35000000000002</td></tr><tr><td>502663</td><td>146.68</td></tr><tr><td>502865</td><td>271.05</td></tr><tr><td>503531</td><td>222.11</td></tr><tr><td>503720</td><td>332.37</td></tr><tr><td>503730</td><td>359.83</td></tr><tr><td>503791</td><td>142.8</td></tr><tr><td>503812</td><td>135.55</td></tr><tr><td>504 ...
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// ## Draw Distribution And Calculate Values for First 85 Quantiles

// %%
%scala
val quantileArray = (0 to 85).map(_ / 100.0).toArray
val quantiles = invoiceTotal.stat.approxQuantile("ItemsTotal", quantileArray, 0.01)

// Convert quantiles to a DataFrame for further processing
val quantileDF = spark.createDataFrame(quantiles.zipWithIndex.map { case (value, index) =>
  (index, value)
}).toDF("Quantile", "ItemsTotal")

// Calculate additional statistics
val minTotal = quantileDF.agg(min("ItemsTotal")).first().getDouble(0)
val maxTotal = quantileDF.agg(max("ItemsTotal")).first().getDouble(0)
val medianTotal = quantiles(quantiles.length / 2)
val meanTotal = invoiceTotal.agg(mean("ItemsTotal")).first().getDouble(0)
val modeTotal = invoiceTotal.groupBy("ItemsTotal")
</td><td>333.02</td></tr><tr><td>59</td><td>338.5000000000001</td></tr><tr><td>60</td><td>349.35</td></tr><tr><td>61</td><td>354.84999999999997</td></tr><tr><td>62</td><td>359.83</td></tr><tr><td>63</td><td>371.01</td></tr><tr><td>64</td><td>376.5799999999999</td></tr><tr><td>65</td><td>382.4699999999999</td></tr><tr><td>66</td><td>394.25000000000006</td></tr><tr><td>67</td><td>400.40000000000003</td></tr><tr><td>68</td><td>413.20000000000005</td></tr><tr><td>69</td><td>419.40000000000003</td></tr><tr><td>70</td><td>431.6299999999999</td></tr><tr><td>71</td><td>438.28000000000003</td></tr><tr><td>72</td><td>452.84999999999985</td></tr><tr><td>73</td><td>466.12</td></tr><tr><td>74</td><td>481.8399999999999</td></tr><tr><td>75</td><td>496.44</td></tr><tr><td>76</td><td>510.8900000000001</td></tr><tr><td>77</td><td>526.2699999999996</td></tr><tr><td>78</td><td>541.3299999999999</td></tr><tr><td>79</td><td>557.84</td></tr><tr><td>80</td><td>584.5000000000001</td></tr><tr><td>81</td><td>600.0</td></tr><tr><td>82</td><td>621.9300000000002</td></tr><tr><td>83</td><td>638.5200000000001</td></tr><tr><td>84</td><td>664.4500000000003</td></tr><tr><td>85</td><td>692.96</td></tr></tbody></table></div>
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// # Monthly Placed and Canceled Orders

// %% [markdown]
// ## Calculate Monthly Placed and Cancelled Orders

// %%
%scala
// Create column to group by month
val dfWithMonth = itemsTotal.withColumn("YYYYMM", date_format(col("InvoiceDate"), "yyyyMM"))

// Calculate Total # of Orders, Cancelled, and Placed
val totalOrders = dfWithMonth.groupBy("YYYYMM").agg(countDistinct("Invoice").alias("TotalOrders"))

val cancelledOrders = dfWithMonth
  .filter(col("Invoice").startsWith("C"))
  .groupBy("YYYYMM")
  .agg(countDistinct("Invoice").alias("CancelledOrders"))

val placedOrders = totalOrders
  .join(cancelledOrders, Seq("YYYYMM"), "left_outer")
  .withColumn("PlacedOrders", col("TotalOrders") - col("CancelledOrders") * 2)
  .select("YYYYMM", "TotalOrders", "CancelledOrders", "PlacedOrders")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">dfWithMonth: org.apache.spark.sql.DataFrame = [Invoice: string, StockCode: string ... 8 more fields]
// totalOrders: org.apache.spark.sql.DataFrame = [YYYYMM: string, TotalOrders: bigint]
// cancelledOrders: org.apache.spark.sql.DataFrame = [YYYYMM: string, CancelledOrders: bigint]
// placedOrders: org.apache.spark.sql.DataFrame = [YYYYMM: string, TotalOrders: bigint ... 2 more fields]
// </div>

// %% [markdown]
// ## Show Distribution of Placed and Cancelled Orders By Month

// %%
%scala

//Reshape dataframe to allow for double bar graph

val cancelledOrdersDF = placedOrders
  .select(
    col("YYYYMM"),
    col("CancelledOrders").alias("OrderCount"),
    lit("CancelledOrders").alias("OrderType")
  )

val placedOrdersDF = placedOrders
  .select(
    col("YYYYMM"),
    col("PlacedOrders").alias("OrderCount"),
    lit("PlacedOrders").alias("OrderType")
  )

// Combine both DataFrames
val combinedOrdersDF = cancelledOrdersDF.union(placedOrdersDF)

display(combinedOrdersDF)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// # Monthly Sales

// %% [markdown]
// ## Calculate Monthly Sales Data

// %%
%scala
val monthlySales = dfWithMonth.groupBy("YYYYMM").agg(sum("ItemsTotal").alias("MonthlySalesTotal"))
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">monthlySales: org.apache.spark.sql.DataFrame = [YYYYMM: string, MonthlySalesTotal: double]
// </div>

// %% [markdown]
// ## Distribution of Sales By Month

// %%
%scala
display(monthlySales)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YYYYMM</th><th>sum(ItemsTotal)</th></tr></thead><tbody><tr><td>201001</td><td>624032.8919999956</td></tr><tr><td>201002</td><td>533091.4260000042</td></tr><tr><td>201007</td><td>575236.360000009</td></tr><tr><td>201004</td><td>590580.4319999823</td></tr><tr><td>200912</td><td>799847.1100000143</td></tr><tr><td>201006</td><td>679786.6099999842</td></tr><tr><td>201005</td><td>615322.8300000005</td></tr><tr><td>201003</td><td>765848.7609999765</td></tr><tr><td>201103</td><td>683267.0800000189</td></tr><tr><td>201104</td><td>493207.1210000249</td></tr><tr><td>201106</td><td>691123.1200000228</td></tr><tr><td>201102</td><td>498062.6500000268</td></tr><tr><td>201107</td><td>681300.1110000301</td></tr><tr><td>201012</td><td>1126445.469999944</td></tr><tr><td>201105</td><td>723333.51000001</td></tr><tr><td>201108</td><td>682680.5100000137</td></tr><tr><td>201101</td><td>560000.2600000234</td></tr><tr><td>201010</td><td>1045168.3499998983</td></tr><tr><td>201009</td><td>853650.4309999745</td></tr><tr><td>201008</td><td>656776.3399999854</td></tr><tr><td>201011</td><td>1422654.6419998251</td></tr><tr><td>201110</td><td>1070704.669999975</td></tr><tr><td>201109</td><td>1019687.622000011</td></tr><tr><td>201111</td><td>1461756.2499997574</td></tr><tr><td>201112</td><td>433686.0100000171</td></tr></tbody></table></div>
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// # Monthly Sales Growth

// %% [markdown]
// ## Calculate Monthly Sales Percentage Growth Data

// %%
%scala
import org.apache.spark.sql.expressions.Window

// Define a window specification for calculating the lag
val windowSpec = Window.orderBy("YYYYMM")

// Add a column for the previous month's ItemsTotal
val monthlySalesWithLag = monthlySales
  .withColumn("PreviousItemsTotal", lag("MonthlySalesTotal", 1).over(windowSpec))

// Calculate the growth rate as a percentage change
val monthlySalesWithGrowthRate = monthlySalesWithLag
  .withColumn("GrowthRate", (col("MonthlySalesTotal") - col("PreviousItemsTotal")) / col("PreviousItemsTotal"))
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YYYYMM</th><th>GrowthRate</th></tr></thead><tbody><tr><td>200912</td><td>null</td></tr><tr><td>201001</td><td>-0.2198097808967711</td></tr><tr><td>201002</td><td>-0.14573184709627782</td></tr><tr><td>201003</td><td>0.4366180426994347</td></tr><tr><td>201004</td><td>-0.22885501410375667</td></tr><tr><td>201005</td><td>0.0418950521544184</td></tr><tr><td>201006</td><td>0.10476416095268813</td></tr><tr><td>201007</td><td>-0.15379863101448504</td></tr><tr><td>201008</td><td>0.14175039282978427</td></tr><tr><td>201009</td><td>0.29975819622246663</td></tr><tr><td>201010</td><td>0.22435169250202086</td></tr><tr><td>201011</td><td>0.36117271633795983</td></tr><tr><td>201012</td><td>-0.20820876919467954</td></tr><tr><td>201101</td><td>-0.5028607465569983</td></tr><tr><td>201102</td><td>-0.11060282364867835</td></tr><tr><td>201103</td><td>0.3718496659004287</td></tr><tr><td>201104</td><td>-0.2781634950127976</td></tr><tr><td>201105</td><td>0.4665917810216968</td></tr><tr><td>201106</td><td>-0.044530482211430744</td></tr><tr><td>201107</td><td>-0.014213110104017964</td></tr><tr><td>201108</td><td>0.0020261247249138007</td></tr><tr><td>201109</td><td>0.4936527512701227</td></tr><tr><td>201110</td><td>0.05003203618368864</td></tr><tr><td>201111</td><td>0.3652282379601384</td></tr><tr><td>201112</td><td>-0.7033116773059195</td></tr></tbody></table></div>
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// ## Plot Chart to Show Growth Percentage

// %%
%scala
// Display the result
display(monthlySalesWithGrowthRate.select("YYYYMM","GrowthRate"))
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YYYYMM</th><th>GrowthRate</th></tr></thead><tbody><tr><td>200912</td><td>null</td></tr><tr><td>201001</td><td>-0.2198097808967711</td></tr><tr><td>201002</td><td>-0.14573184709627782</td></tr><tr><td>201003</td><td>0.4366180426994347</td></tr><tr><td>201004</td><td>-0.22885501410375667</td></tr><tr><td>201005</td><td>0.0418950521544184</td></tr><tr><td>201006</td><td>0.10476416095268813</td></tr><tr><td>201007</td><td>-0.15379863101448504</td></tr><tr><td>201008</td><td>0.14175039282978427</td></tr><tr><td>201009</td><td>0.29975819622246663</td></tr><tr><td>201010</td><td>0.22435169250202086</td></tr><tr><td>201011</td><td>0.36117271633795983</td></tr><tr><td>201012</td><td>-0.20820876919467954</td></tr><tr><td>201101</td><td>-0.5028607465569983</td></tr><tr><td>201102</td><td>-0.11060282364867835</td></tr><tr><td>201103</td><td>0.3718496659004287</td></tr><tr><td>201104</td><td>-0.2781634950127976</td></tr><tr><td>201105</td><td>0.4665917810216968</td></tr><tr><td>201106</td><td>-0.044530482211430744</td></tr><tr><td>201107</td><td>-0.014213110104017964</td></tr><tr><td>201108</td><td>0.0020261247249138007</td></tr><tr><td>201109</td><td>0.4936527512701227</td></tr><tr><td>201110</td><td>0.05003203618368864</td></tr><tr><td>201111</td><td>0.3652282379601384</td></tr><tr><td>201112</td><td>-0.7033116773059195</td></tr></tbody></table></div>
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// # Monthly Active Users

// %% [markdown]
// ## Calculate Monthly Active Users

// %%
%scala
val monthlyUsers = dfWithMonth
  .groupBy("YYYYMM")
  .agg(countDistinct("Customer ID").alias("UniqueUsersPerMonth"))
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">monthlyUsers: org.apache.spark.sql.DataFrame = [YYYYMM: string, UniqueUsersPerMonth: bigint]
// </div>

// %% [markdown]
// ## Plot Bar Chart For Monthly Active Users

// %%
%scala
display(monthlyUsers)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YYYYMM</th><th>UniqueUsersPerMonth</th></tr></thead><tbody><tr><td>201103</td><td>1020</td></tr><tr><td>201001</td><td>786</td></tr><tr><td>201002</td><td>807</td></tr><tr><td>201010</td><td>1577</td></tr><tr><td>201009</td><td>1202</td></tr><tr><td>201104</td><td>899</td></tr><tr><td>201106</td><td>1051</td></tr><tr><td>201102</td><td>798</td></tr><tr><td>201110</td><td>1425</td></tr><tr><td>201008</td><td>964</td></tr><tr><td>201107</td><td>993</td></tr><tr><td>201012</td><td>948</td></tr><tr><td>201105</td><td>1079</td></tr><tr><td>201109</td><td>1302</td></tr><tr><td>201011</td><td>1683</td></tr><tr><td>201007</td><td>988</td></tr><tr><td>201111</td><td>1711</td></tr><tr><td>201108</td><td>980</td></tr><tr><td>201112</td><td>686</td></tr><tr><td>201004</td><td>998</td></tr><tr><td>200912</td><td>1045</td></tr><tr><td>201006</td><td>1095</td></tr><tr><td>201005</td><td>1062</td></tr><tr><td>201101</td><td>783</td></tr><tr><td>201003</td><td>1111</td></tr></tbody></table></div>
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// # New and Existing Users

// %% [markdown]
// ## Merge Tables To Find New And Existing Users

// %%
%scala
// Find out purchase date of Each customer Id
val firstPurchase = dfWithMonth.groupBy("Customer ID").agg(min("YYYYMM").alias("FirstPurchaseDate"))

// Join the first purchase date back to the original DataFrame
val dfWithFirstPurchase = dfWithMonth
  .join(firstPurchase, Seq("Customer ID"), "left_outer")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">firstPurchase: org.apache.spark.sql.DataFrame = [Customer ID: double, FirstPurchaseDate: string]
// dfWithFirstPurchase: org.apache.spark.sql.DataFrame = [Customer ID: double, Invoice: string ... 9 more fields]
// </div>

// %% [markdown]
// ## Find Values of New And Existing Users Per Month

// %%
%scala
//find new users
val newUsers = dfWithFirstPurchase
  .filter(col("YYYYMM") === col("FirstPurchaseDate"))

// Count unique new users per month
val newUsersPerMonth = newUsers
  .groupBy("YYYYMM")
  .agg(countDistinct("Customer ID").alias("NewUsers"))
  
// Step 3: Find existing users
val existingUsers = dfWithFirstPurchase
  .filter(col("YYYYMM") =!= col("FirstPurchaseDate"))

//   Count unique existing users per month
val existingUsersPerMonth = existingUsers
  .groupBy("YYYYMM")
  .agg(countDistinct("Customer ID").alias("ExistingUsers"))
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">newUsers: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [Customer ID: double, Invoice: string ... 9 more fields]
// newUsersPerMonth: org.apache.spark.sql.DataFrame = [YYYYMM: string, NewUsers: bigint]
// existingUsers: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [Customer ID: double, Invoice: string ... 9 more fields]
// existingUsersPerMonth: org.apache.spark.sql.DataFrame = [YYYYMM: string, ExistingUsers: bigint]
// </div>

// %% [markdown]
// ## Plot Data Of New And Existing Users By Month

// %%
%scala
// Combine new and existing users DataFrames
val newUsersWithType = newUsersPerMonth
  .withColumnRenamed("NewUsers", "NewUserCount")

// Prepare existing users DataFrame
val existingUsersWithType = existingUsersPerMonth
  .withColumnRenamed("ExistingUsers", "ExUserCount")

// Merge new and existing users DataFrames on YYYYMM
val newEx = newUsersWithType
  .join(existingUsersWithType, Seq("YYYYMM"), "outer")

// Reshape DataFrame for side-by-side bar chart
val reshapedDF = newEx
  .select(col("YYYYMM"), 
          col("NewUserCount"), 
          col("ExUserCount"))
  .withColumn("UserType", lit("New Users"))
  .select(col("YYYYMM"), col("NewUserCount"), col("UserType"))
  .union(newEx.select(col("YYYYMM"), 
                      col("ExUserCount").alias("UserCount"), 
                      lit("Existing Users").alias("UserType")))
  .withColumnRenamed("NewUserCount", "UserCount")

display(reshapedDF)
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YYYYMM</th><th>UserCount</th><th>UserType</th></tr></thead><tbody><tr><td>200912</td><td>1045</td><td>New Users</td></tr><tr><td>201001</td><td>394</td><td>New Users</td></tr><tr><td>201002</td><td>363</td><td>New Users</td></tr><tr><td>201003</td><td>436</td><td>New Users</td></tr><tr><td>201004</td><td>291</td><td>New Users</td></tr><tr><td>201005</td><td>254</td><td>New Users</td></tr><tr><td>201006</td><td>269</td><td>New Users</td></tr><tr><td>201007</td><td>183</td><td>New Users</td></tr><tr><td>201008</td><td>158</td><td>New Users</td></tr><tr><td>201009</td><td>242</td><td>New Users</td></tr><tr><td>201010</td><td>379</td><td>New Users</td></tr><tr><td>201011</td><td>322</td><td>New Users</td></tr><tr><td>201012</td><td>77</td><td>New Users</td></tr><tr><td>201101</td><td>71</td><td>New Users</td></tr><tr><td>201102</td><td>123</td><td>New Users</td></tr><tr><td>201103</td><td>178</td><td>New Users</td></tr><tr><td>201104</td><td>105</td><td>New Users</td></tr><tr><td>201105</td><td>108</td><td>New Users</td></tr><tr><td>201106</td><td>108</td><td>New Users</td></tr><tr><td>201107</td><td>102</td><td>New Users</td></tr><tr><td>201108</td><td>106</td><td>New Users</td></tr><tr><td>201109</td><td>187</td><td>New Users</td></tr><tr><td>201110</td><td>221</td><td>New Users</td></tr><tr><td>201111</td><td>192</td><td>New Users</td></tr><tr><td>201112</td><td>28</td><td>New Users</td></tr><tr><td>200912</td><td>null</td><td>Existing Users</td></tr><tr><td>201001</td><td>392</td><td>Existing Users</td></tr><tr><td>201002</td><td>444</td><td>Existing Users</td></tr><tr><td>201003</td><td>675</td><td>Existing Users</td></tr><tr><td>201004</td><td>707</td><td>Existing Users</td></tr><tr><td>201005</td><td>808</td><td>Existing Users</td></tr><tr><td>201006</td><td>826</td><td>Existing Users</td></tr><tr><td>201007</td><td>805</td><td>Existing Users</td></tr><tr><td>201008</td><td>806</td><td>Existing Users</td></tr><tr><td>201009</td><td>960</td><td>Existing Users</td></tr><tr><td>201010</td><td>1198</td><td>Existing Users</td></tr><tr><td>201011</td><td>1361</td><td>Existing Users</td></tr><tr><td>201012</td><td>871</td><td>Existing Users</td></tr><tr><td>201101</td><td>712</td><td>Existing Users</td></tr><tr><td>201102</td><td>675</td><td>Existing Users</td></tr><tr><td>201103</td><td>842</td><td>Existing Users</td></tr><tr><td>201104</td><td>794</td><td>Existing Users</td></tr><tr><td>201105</td><td>971</td><td>Existing Users</td></tr><tr><td>201106</td><td>943</td><td>Existing Users</td></tr><tr><td>201107</td><td>891</td><td>Existing Users</td></tr><tr><td>201108</td><td>874</td><td>Existing Users</td></tr><tr><td>201109</td><td>1115</td><td>Existing Users</td></tr><tr><td>201110</td><td>1204</td><td>Existing Users</td></tr><tr><td>201111</td><td>1519</td><td>Existing Users</td></tr><tr><td>201112</td><td>658</td><td>Existing Users</td></tr></tbody></table></div>
// Databricks visualization. Run in Databricks to view.

// %% [markdown]
// ## Calculating Recency, Monetary and Frequency Values

// %%
%scala
import java.time.LocalDate
import java.time.format.DateTimeFormatter

// Set today's date
val today = LocalDate.now()

// Calculating recency and monetary values
val dfX = dfWithMonth
  .groupBy("Customer ID")
  .agg(
    sum("ItemsTotal").alias("MonetaryValue"), // monetary value
    datediff(lit(today.toString), max("InvoiceDate")).alias("RecencyValue") // recency value
  )

// Calculate frequency values
// Calculate frequency values
val dfY = dfWithMonth
  .groupBy("Customer ID", "Invoice")
  .agg(sum("ItemsTotal").alias("TotalItems")) // Sum of ItemsTotal for each Invoice

val dfZ = dfY
  .groupBy("Customer ID")
  .agg(count("TotalItems").alias("FrequencyValue")) // Count of distinct invoices for each CustomerId
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">import java.time.LocalDate
// import java.time.format.DateTimeFormatter
// today: java.time.LocalDate = 2024-11-03
// dfX: org.apache.spark.sql.DataFrame = [Customer ID: double, MonetaryValue: double ... 1 more field]
// dfY: org.apache.spark.sql.DataFrame = [Customer ID: double, Invoice: string ... 1 more field]
// dfZ: org.apache.spark.sql.DataFrame = [Customer ID: double, FrequencyValue: bigint]
// </div>

// %% [markdown]
// ## Merge values into a single table

// %%
%scala

// Merge dfX and dfZ on 'CustomerId' to create the RFM table
val rfmTable = dfX.join(dfZ, Seq("Customer ID"), "inner")
  .select("Customer ID", "RecencyValue", "FrequencyValue", "MonetaryValue") // Selecting relevant columns


// determination of column names
val renamedRfmTable = rfmTable
  .withColumnRenamed("RecencyValue", "Recency")
  .withColumnRenamed("FrequencyValue", "Frequency")
  .withColumnRenamed("MonetaryValue", "Monetary")
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">rfmTable: org.apache.spark.sql.DataFrame = [Customer ID: double, RecencyValue: int ... 2 more fields]
// renamedRfmTable: org.apache.spark.sql.DataFrame = [Customer ID: double, Recency: int ... 2 more fields]
// </div>

// %% [markdown]
// ## Calculate RFM Score Values

// %%
%scala
val recencyScore = renamedRfmTable
  .withColumn("RecencyScore", ntile(5).over(Window.orderBy("Recency")))

val frequencyScore = recencyScore
  .withColumn("FrequencyScore", ntile(5).over(Window.orderBy(col("Frequency").desc)))

val monetaryScore = frequencyScore
  .withColumn("MonetaryScore", ntile(5).over(Window.orderBy(col("Monetary").desc)))

val rfmWithScores = monetaryScore
  .withColumn("RFM_SCORE", concat_ws("", col("RecencyScore"), col("FrequencyScore"), col("MonetaryScore")))
// Out:
// <style scoped>
//   .ansiout {
//     display: block;
//     unicode-bidi: embed;
//     white-space: pre-wrap;
//     word-wrap: break-word;
//     word-break: break-all;
//     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
//     font-size: 13px;
//     color: #555;
//     margin-left: 4px;
//     line-height: 19px;
//   }
// </style>
// <div class="ansiout">recencyScore: org.apache.spark.sql.DataFrame = [Customer ID: double, Recency: int ... 3 more fields]
// frequencyScore: org.apache.spark.sql.DataFrame = [Customer ID: double, Recency: int ... 4 more fields]
// monetaryScore: org.apache.spark.sql.DataFrame = [Customer ID: double, Recency: int ... 5 more fields]
// rfmWithScores: org.apache.spark.sql.DataFrame = [Customer ID: double, Recency: int ... 6 more fields]
// </div>

// %% [markdown]
// # RFM Segmentation

// %%
%scala
// segmenting of customers according to RecencyScore and FrequencyScore values using map
val segMap = Map(
  "[1-2][1-2]" -> "Hibernating",
  "[1-2][3-4]" -> "At Risk",
  "[1-2]5" -> "Can't Lose",
  "3[1-2]" -> "About to Sleep",
  "33" -> "Need Attention",
  "[3-4][4-5]" -> "Loyal Customers",
  "41" -> "Promising",
  "51" -> "New Customers",
  "[4-5][2-3]" -> "Potential Loyalists",
  "5[4-5]" -> "Champions"
)

// creation of segment variable
val rfmWithSegments = rfmWithScores
  .withColumn("Segment", concat(col("RecencyScore").cast("string"), col("FrequencyScore").cast("string")))

// Replace segment values using the defined regex map
val segmentedRFMTable = segMap.foldLeft(rfmWithSegments) {
  case (df, (pattern, segmentName)) =>
    df.withColumn("Segment", when(col("Segment").rlike(pattern), segmentName).otherwise(col("Segment")))
}
// Out:
// <style scoped>
//   .table-result-container {
//     max-height: 300px;
//     overflow: auto;
//   }
//   table, th, td {
//     border: 1px solid black;
//     border-collapse: collapse;
//   }
//   th, td {
//     padding: 5px;
//   }
//   th {
//     text-align: left;
//   }
// </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Customer ID</th><th>Recency</th><th>Frequency</th><th>Monetary</th><th>RecencyScore</th><th>FrequencyScore</th><th>MonetaryScore</th><th>RFM_SCORE</th><th>Segment</th></tr></thead><tbody><tr><td>18102.0</td><td>4713</td><td>153</td><td>598215.2200000002</td><td>1</td><td>1</td><td>1</td><td>111</td><td>Hibernating</td></tr><tr><td>14646.0</td><td>4714</td><td>164</td><td>523342.0699999989</td><td>1</td><td>1</td><td>1</td><td>111</td><td>Hibernating</td></tr><tr><td>14156.0</td><td>4722</td><td>202</td><td>296564.68999999965</td><td>1</td><td>1</td><td>1</td><td>111</td><td>Hibernating</td></tr><tr><td>14911.0</td><td>4714</td><td>510</td><td>270248.52999999974</td><td>1</td><td>1</td><td>1</td><td>111</td><td>Hibernating</td></tr><tr><td>17450.0</td><td>4721</td><td>61</td><td>233579.38999999998</td><td>1</td><td>1</td><td>1</td><td>111</td><td>Hibernating</td></tr><tr><td>13694.0</td><td>4716</td><td>164</td